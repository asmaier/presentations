# %%
import pandas as pd
import pycaret.time_series as pyts

# %%
df = pd.read_csv("20230503_090829.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Time        394 non-null    object
#  1   MAX(count)  394 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 6.3+ KB

# %%
df.index = pd.to_datetime(df.Time)

# %%
df2 = df.drop("Time", axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 394 entries, 2022-04-05 00:00:00+00:00 to 2023-05-03 00:00:00+00:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MAX(count)  394 non-null    float64
# dtypes: float64(1)
# memory usage: 6.2 KB

# %%
df2.rename(columns={"MAX(count)": "timeoff"})
# Out:
#                            timeoff
# Time
# 2022-04-05 00:00:00+00:00     10.0
# 2022-04-06 00:00:00+00:00     10.0
# 2022-04-07 00:00:00+00:00      8.0
# 2022-04-08 00:00:00+00:00     13.0
# 2022-04-09 00:00:00+00:00      8.0
# ...                            ...
# 2023-04-29 00:00:00+00:00      7.0
# 2023-04-30 00:00:00+00:00      7.0
# 2023-05-01 00:00:00+00:00      8.0
# 2023-05-02 00:00:00+00:00     10.0
# 2023-05-03 00:00:00+00:00      7.0
#
# [394 rows x 1 columns]

# %%
df2.plot()
# Out:
# <Axes: xlabel='Time'>

# %%
exp = pyts.TSForecastingExperiment()
# exp.setup(df2, fh=7, session_id=42)

# %%
exp.setup(df2, fh=7, session_id=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 exp.setup(df2, fh=7, session_id=42)
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/pycaret/time_series/forecasting/oop.py:1984, in TSForecastingExperiment.setup(self, data, data_func, target, index, ignore_features, numeric_imputation_target, numeric_imputation_exogenous, transform_target, transform_exogenous, scale_target, scale_exogenous, fe_target_rr, fe_exogenous, fold_strategy, fold, fh, hyperparameter_split, seasonal_period, ignore_seasonality_test, sp_detection, max_sp_to_consider, remove_harmonics, harmonic_order_method, num_sps_to_use, point_alpha, coverage, enforce_exogenous, n_jobs, use_gpu, custom_pipeline, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, profile, profile_kwargs, fig_kwargs)
#    1980 # Features to be ignored (are not read by self.dataset, self.X, etc...)
#    1981 self._fxs = {"Ignore": ignore_features or []}
#    1983 (
# -> 1984     self._initialize_setup(
#    1985         n_jobs=n_jobs,
#    1986         use_gpu=use_gpu,
#    1987         html=html,
#    1988         session_id=session_id,
#    1989         system_log=system_log,
#    1990         log_experiment=log_experiment,
#    1991         experiment_name=experiment_name,
#    1992         memory=True,
#    1993         verbose=verbose,
#    1994     )
#    1995     ._check_clean_and_set_data(data)
#    1996     ._check_and_clean_index(index=index, seasonal_period=seasonal_period)
#    1997     ._check_and_set_targets(target=target)
#    1998     ._set_exogenous_names()
#    1999     ._check_and_set_forecasting_types()
#    2000     ._check_and_set_fh(fh=fh)
#    2001     ._set_point_alpha_intervals_enforce_pi(
#    2002         point_alpha=point_alpha, coverage=coverage
#    2003     )
#    2004     ._setup_train_test_split()
#    2005     ._set_fold_generator()
#    2006     ._set_should_preprocess_data()
#    2007     ._set_missingness()
#    2008     ._initialize_pipeline()
#    2009     ##################################################################
#    2010     # Do these after the preprocessing pipeline has been setup.
#    2011     # Since the model will see transformed data, these parameters
#    2012     # should also be derived from the transformed data.
#    2013     ##################################################################
#    2014     ._check_and_set_seasonal_period()
#    2015     ._set_multiplicative_components()
#    2016     ._perform_setup_eda()
#    2017     ._setup_display_container()
#    2018     ._profile(profile, profile_kwargs)
#    2019     ._set_exp_model_engines(
#    2020         container_default_engines=get_container_default_engines(),
#    2021         engine=engine,
#    2022     )
#    2023     ._set_all_models()
#    2024     ._set_all_metrics()
#    2025 )
#    2027 runtime = np.array(time.time() - runtime_start).round(2)
#    2029 self._set_up_logging(
#    2030     runtime,
#    2031     log_data,
#    2032     log_profile,
#    2033     experiment_custom_tags=experiment_custom_tags,
#    2034 )
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/pycaret/time_series/forecasting/oop.py:1123, in TSForecastingExperiment._initialize_pipeline(self)
#    1110     self._scaling(
#    1111         scale_target=self.scale_target,
#    1112         scale_exogenous=self.scale_exogenous,
#    1113         exogenous_present=self.exogenous_present,
#    1114     )
#    1116 # TODO Add custom transformers to the pipeline
#    1117 # if custom_pipeline:
#    1118 #     self._add_custom_pipeline(custom_pipeline)
#    1119 # TODO: When adding custom pipeline, also add checks to make sure:
#    1120 # (1) 1st step for both X and y is Imputer
#    1121 # (2) If 1st step is imputer, there can be other imputers as well.
# -> 1123 self.pipeline = self._create_pipeline(
#    1124     model=DummyForecaster(),
#    1125     transformer_steps_target=self.transformer_steps_target,
#    1126     transformer_steps_exogenous=self.transformer_steps_exogenous,
#    1127 )
#    1128 self._check_pipeline()
#    1130 self.pipeline_fully_trained = deepcopy(self.pipeline)
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/pycaret/time_series/forecasting/oop.py:4755, in TSForecastingExperiment._create_pipeline(self, model, transformer_steps_target, transformer_steps_exogenous)
#    4753     steps_target.extend([("transformer_target", transformer_target)])
#    4754 steps_target.extend([("model", model)])
# -> 4755 forecaster = TransformedTargetForecaster(steps_target)
#    4757 # Create Forecasting Pipeline ----
#    4758 steps_exogenous = []
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/sktime/forecasting/compose/_pipeline.py:827, in TransformedTargetForecaster.__init__(self, steps)
#     825 def __init__(self, steps):
#     826     self.steps = steps
# --> 827     self.steps_ = self._check_steps(steps, allow_postproc=True)
#     828     super(TransformedTargetForecaster, self).__init__()
#     830     # set the tags based on forecaster
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/sktime/forecasting/compose/_pipeline.py:93, in _Pipeline._check_steps(self, estimators, allow_postproc)
#      85     msg = (
#      86         f"in {self_name}, found steps of length 1, "
#      87         f"this will result in the same behaviour "
#      88         f"as not wrapping the single step in a pipeline. "
#      89         f"Consider not wrapping steps in {self_name} as it is redundant."
#      90     )
#      91     warn(msg)
# ---> 93 estimator_tuples = self._get_estimator_tuples(estimators, clone_ests=True)
#      94 names, estimators = zip(*estimator_tuples)
#      96 # validate names
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/sktime/base/_meta.py:377, in _HeterogenousMetaEstimator._get_estimator_tuples(self, estimators, clone_ests)
#     375 ests = self._get_estimator_list(estimators)
#     376 if clone_ests:
# --> 377     ests = [e.clone() for e in ests]
#     378 unique_names = self._get_estimator_names(estimators, make_unique=True)
#     379 est_tuples = list(zip(unique_names, ests))
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/sktime/base/_meta.py:377, in <listcomp>(.0)
#     375 ests = self._get_estimator_list(estimators)
#     376 if clone_ests:
# --> 377     ests = [e.clone() for e in ests]
#     378 unique_names = self._get_estimator_names(estimators, make_unique=True)
#     379 est_tuples = list(zip(unique_names, ests))
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/skbase/base/_base.py:164, in BaseObject.clone(self)
#     161 if not self.get_config()["check_clone"]:
#     162     return self_clone
# --> 164 from skbase.testing.utils.deep_equals import deep_equals
#     166 # check that all attributes are written to the clone
#     167 for attrname in self_params.keys():
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/skbase/testing/__init__.py:5
#       2 """:mod:`skbase.testing` provides a framework to test ``BaseObject``-s."""
#       3 from typing import List
# ----> 5 from skbase.testing.test_all_objects import (
#       6     BaseFixtureGenerator,
#       7     QuickTester,
#       8     TestAllObjects,
#       9 )
#      11 __all__: List[str] = ["BaseFixtureGenerator", "QuickTester", "TestAllObjects"]
#      12 __author__: List[str] = ["fkiraly"]
#
# File ~/.local/share/virtualenvs/timeseries-zVXJwwgX/lib/python3.9/site-packages/skbase/testing/test_all_objects.py:14
#      11 from typing import List
#      13 import numpy as np
# ---> 14 import pytest
#      16 from skbase.base import BaseObject
#      17 from skbase.lookup import all_objects
#
# ModuleNotFoundError: No module named 'pytest'
